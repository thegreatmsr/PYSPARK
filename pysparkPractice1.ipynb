# %%
# Out:
#      <input type="file" id="files-d93b033a-4fb2-4932-b636-d7f2e2940a1e" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-d93b033a-4fb2-4932-b636-d7f2e2940a1e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df = spark.read.csv("username.csv", header=True, inferSchema=True)
df.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-4181890010> in <cell line: 0>()
# ----> 1 df = spark.read.csv("username.csv", header=True, inferSchema=True)
#       2 df.show()
#
# NameError: name 'spark' is not defined

# %%
# !apt-get install openjdk-11-jdk-headless -qq > /dev/null
# !wget -q https://archive.apache.org/dist/spark/spark-3.4.1/spark-3.4.1-bin-hadoop3.tgz
# !tar xf spark-3.4.1-bin-hadoop3.tgz
# !pip install -q findspark

import os
os.environ["JAVA_HOME"] = "/usr/lib/jvm/java-11-openjdk-amd64"
os.environ["SPARK_HOME"] = "/content/spark-3.4.1-bin-hadoop3"

import findspark
findspark.init()

from pyspark.sql import SparkSession

spark = SparkSession.builder \
    .appName("PySparkOnColab") \
    .master("local[*]") \
    .getOrCreate()

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-9f414d75-8ed7-4343-81b2-861f32bca6df" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-9f414d75-8ed7-4343-81b2-861f32bca6df">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df = spark.read.csv("username.csv", header=True, inferSchema=True)
df.show()
# Out:
# +-----------------------------------------+
# |Username; Identifier;First name;Last name|
# +-----------------------------------------+
# |                     booker12;9012;Rac...|
# |                     grey07;2070;Laura...|
# |                     johnson81;4081;Cr...|
# |                     jenkins46;9346;Ma...|
# |                     smith79;5079;Jami...|
# +-----------------------------------------+

# %%
df = spark.read.csv("username.csv", header=True, inferSchema=True, sep=";")
df.show()
# Out:
# +---------+-----------+----------+---------+
# | Username| Identifier|First name|Last name|
# +---------+-----------+----------+---------+
# | booker12|       9012|    Rachel|   Booker|
# |   grey07|       2070|     Laura|     Grey|
# |johnson81|       4081|     Craig|  Johnson|
# |jenkins46|       9346|      Mary|  Jenkins|
# |  smith79|       5079|     Jamie|    Smith|
# +---------+-----------+----------+---------+

# %%
spark.sql("SELECT * FROM users").show()
# Out:
# ---------------------------------------------------------------------------
# AnalysisException                         Traceback (most recent call last)
# <ipython-input-8-227088203> in <cell line: 0>()
# ----> 1 spark.sql("SELECT * FROM users").show()
#
# /content/spark-3.4.1-bin-hadoop3/python/pyspark/sql/session.py in sql(self, sqlQuery, args, **kwargs)
#    1438         try:
#    1439             litArgs = {k: _to_java_column(lit(v)) for k, v in (args or {}).items()}
# -> 1440             return DataFrame(self._jsparkSession.sql(sqlQuery, litArgs), self)
#    1441         finally:
#    1442             if len(kwargs) > 0:
#
# /content/spark-3.4.1-bin-hadoop3/python/lib/py4j-0.10.9.7-src.zip/py4j/java_gateway.py in __call__(self, *args)
#    1320
#    1321         answer = self.gateway_client.send_command(command)
# -> 1322         return_value = get_return_value(
#    1323             answer, self.gateway_client, self.target_id, self.name)
#    1324
#
# ...

# %%
df.createOrReplaceTempView("users")

# %%
spark.sql("SELECT * FROM users").show()
# Out:
# +---------+-----------+----------+---------+
# | Username| Identifier|First name|Last name|
# +---------+-----------+----------+---------+
# | booker12|       9012|    Rachel|   Booker|
# |   grey07|       2070|     Laura|     Grey|
# |johnson81|       4081|     Craig|  Johnson|
# |jenkins46|       9346|      Mary|  Jenkins|
# |  smith79|       5079|     Jamie|    Smith|
# +---------+-----------+----------+---------+

# %%
spark.sql("SELECT COUNT(*) FROM users").show()
# Out:
# +--------+
# |count(1)|
# +--------+
# |       5|
# +--------+

# %%
spark.sql("SELECT Username FROM Users where Identifier=9012").show()
# Out:
# ---------------------------------------------------------------------------
# AnalysisException                         Traceback (most recent call last)
# <ipython-input-15-2336759655> in <cell line: 0>()
# ----> 1 spark.sql("SELECT Username FROM Users where Identifier=9012").show()
#
# /content/spark-3.4.1-bin-hadoop3/python/pyspark/sql/session.py in sql(self, sqlQuery, args, **kwargs)
#    1438         try:
#    1439             litArgs = {k: _to_java_column(lit(v)) for k, v in (args or {}).items()}
# -> 1440             return DataFrame(self._jsparkSession.sql(sqlQuery, litArgs), self)
#    1441         finally:
#    1442             if len(kwargs) > 0:
#
# /content/spark-3.4.1-bin-hadoop3/python/lib/py4j-0.10.9.7-src.zip/py4j/java_gateway.py in __call__(self, *args)
#    1320
#    1321         answer = self.gateway_client.send_command(command)
# -> 1322         return_value = get_return_value(
#    1323             answer, self.gateway_client, self.target_id, self.name)
# ...

# %%
spark.sql("SELECT Username FROM Users where Identifier=9012").show()
# Out:
# ---------------------------------------------------------------------------
# AnalysisException                         Traceback (most recent call last)
# <ipython-input-16-2336759655> in <cell line: 0>()
# ----> 1 spark.sql("SELECT Username FROM Users where Identifier=9012").show()
#
# /content/spark-3.4.1-bin-hadoop3/python/pyspark/sql/session.py in sql(self, sqlQuery, args, **kwargs)
#    1438         try:
#    1439             litArgs = {k: _to_java_column(lit(v)) for k, v in (args or {}).items()}
# -> 1440             return DataFrame(self._jsparkSession.sql(sqlQuery, litArgs), self)
#    1441         finally:
#    1442             if len(kwargs) > 0:
#
# /content/spark-3.4.1-bin-hadoop3/python/lib/py4j-0.10.9.7-src.zip/py4j/java_gateway.py in __call__(self, *args)
#    1320
#    1321         answer = self.gateway_client.send_command(command)
# -> 1322         return_value = get_return_value(
#    1323             answer, self.gateway_client, self.target_id, self.name)
# ...

# %%
spark.sql("SELECT username FROM users WHERE Identifier = 9012").show()
# Out:
# ---------------------------------------------------------------------------
# AnalysisException                         Traceback (most recent call last)
# <ipython-input-17-3368274193> in <cell line: 0>()
# ----> 1 spark.sql("SELECT username FROM users WHERE Identifier = 9012").show()
#
# /content/spark-3.4.1-bin-hadoop3/python/pyspark/sql/session.py in sql(self, sqlQuery, args, **kwargs)
#    1438         try:
#    1439             litArgs = {k: _to_java_column(lit(v)) for k, v in (args or {}).items()}
# -> 1440             return DataFrame(self._jsparkSession.sql(sqlQuery, litArgs), self)
#    1441         finally:
#    1442             if len(kwargs) > 0:
#
# /content/spark-3.4.1-bin-hadoop3/python/lib/py4j-0.10.9.7-src.zip/py4j/java_gateway.py in __call__(self, *args)
#    1320
#    1321         answer = self.gateway_client.send_command(command)
# -> 1322         return_value = get_return_value(
#    1323             answer, self.gateway_client, self.target_id, self.name)
# ...

# %%
spark.sql("SELECT `Username` FROM users WHERE ` Identifier` = 9012").show()
# Out:
# +--------+
# |Username|
# +--------+
# |booker12|
# +--------+

# %%
spark.version        # Shows Spark version
spark.sparkContext.master  # Show the execution mode: 'local[*]'
# Out:
# 'local[*]'

# %%
data = [1, 2, 3, 4, 5]
rdd = spark.sparkContext.parallelize(data)
rdd.collect()
# Out:
# [1, 2, 3, 4, 5]

# %%
rdd2 = rdd.map(lambda x: x * 2)
# No computation happens yet
rdd2.collect()  # Now Spark runs!
print(rdd2.collect())
# Out:
# [2, 4, 6, 8, 10]
